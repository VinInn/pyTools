# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
import os
import re
import matplotlib
import matplotlib.pyplot as plt
import glob
import math
import numpy as np
import jax as jp
import jax.numpy as jnp
from jax import jit

# %%
x = np.array([884279719003555.0,1.2,2.4,2.1,2.0]);
y = np.array([884279719003555.0,1.2,2.4,2.1,2.0]);

# %%
def foo(x,y) :
    return x*x - y*y
def foo2(x,y) :
    x2 = x*x
    y2 = y*y
    return x2 - y2

# %%
z=foo(x,y)
print(z)
# Out:
# [0. 0. 0. 0. 0.]

# %%
xj = jnp.array([884279719003555.0,1.2,2.4,2.1,2.0]);
yj = jnp.array([884279719003555.0,1.2,2.4,2.1,2.0]);
fooj = jit(foo)
foo2j = jit(foo2)

zj=fooj(xj,yj)
print(zj)
zj=foo2j(xj,yj)
print(zj)
# Out:
# [ 9.0327392e+21 -5.7220461e-08 -2.2888185e-07 -2.2888185e-07
#   0.0000000e+00]
# [ 9.0327392e+21 -5.7220461e-08 -2.2888185e-07 -2.2888185e-07
#   0.0000000e+00]

# %%
def fma(a,b,c) :
    return a*b+c
fmaj = jit(fma)
def kahanDet(a, b, c, d) :  # a*d-b*c 
   w = b*c 
   e = w - b*c # error on w: (w,-e) = augmentedMultiply(b,c)
   f = a*d - w 
   return (f+e) 

kdj = jit(kahanDet)

# %%
zj=kdj(xj,yj,yj,xj)
print(zj)
# Out:
# [0. 0. 0. 0. 0.]
